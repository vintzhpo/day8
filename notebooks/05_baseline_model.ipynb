# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier

df=pd.read_csv('../data/features_df.csv')

y = df['is_churned']
X = df.drop(columns=['is_churned','customer_id'], errors='ignore')

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

dummy= DummyClassifier(strategy='most_frequent')
dummy.fit(X_train, y_train)
dummy_pred = dummy.predict(X_test)

model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
model_pred = model.predict(X_test)



print("--- ҮР ДҮНГИЙН ХАРЬЦУУЛАЛТ ---")
print(f"Test датанд байгаа БОДИТ цуцлалт (1): {y_test.sum()} хүн")
print(f"Dumb Baseline-ийн таасан цуцлалт (1): {dummy_pred.sum()} хүн")
print(f"Logistic Regression-ийн таасан цуцлалт (1): {model_pred.sum()} хүн")

print("\n--- НАРИЙВЧЛАЛ (Accuracy) ---")
print(f"Dumb Baseline Accuracy: {accuracy_score(y_test, dummy_pred)*100:.2f}%")
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, model_pred)*100:.2f}%")
# Out:
# --- ҮР ДҮНГИЙН ХАРЬЦУУЛАЛТ ---
# Test датанд байгаа БОДИТ цуцлалт (1): 297 хүн
# Dumb Baseline-ийн таасан цуцлалт (1): 0 хүн
# Logistic Regression-ийн таасан цуцлалт (1): 133 хүн
#
# --- НАРИЙВЧЛАЛ (Accuracy) ---
# Dumb Baseline Accuracy: 81.44%
# Logistic Regression Accuracy: 83.38%
